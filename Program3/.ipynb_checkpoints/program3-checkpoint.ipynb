# %%
import pandas as pd
data = pd.read_csv('Housing1.csv')
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 563   1750000  3620         2          1        1      yes        no       no
# 564   1750000  2910         3          1        1       no        no       no
# 565   1750000  3850         3          1        2      yes        no       no
# 566  12250000  8960         4          4        4      yes        no       no
# 567  12250000  9960         3          2        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 563              no              no        0       no      unfurnished
# 564              no              no        0       no        furnished
# 565              no              no        0       no      unfurnished
# 566              no             yes        3       no        furnished
# 567              no              no        2      yes   semi-furnished
#
#      Unnamed: 13  offer
# 0            NaN      1
# 1            NaN      1
# 2            NaN      1
# 3            NaN      1
# 4            NaN      1
# ..           ...    ...
# 563          NaN      1
# 564          NaN      1
# 565          NaN      1
# 566          NaN      1
# 567          NaN      1
#
# [568 rows x 15 columns]

# %%
#Data pre processing

#data cleaning
# Check for missing values
print(data.isnull().sum())
# Out:
# price                 0
# area                  0
# bedrooms              0
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement              0
# hotwaterheating       0
# airconditioning       0
# parking               0
# prefarea              0
# furnishingstatus      0
# Unnamed: 13         568
# offer                 0
# dtype: int64

# %%
# Remove rows with missing values
data = data.dropna()
data
# Out:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus, Unnamed: 13, offer]
# Index: []

# %%
#data integration
# Merge data from two datasets based on a common column
data = pd.read_csv('Housing1.csv')
data1 = pd.read_csv('Housing2.csv')
data_merged = pd.merge(data, data1, on='price')

# %%
data_merged
# Out:
#        price  area_x  bedrooms_x  bathrooms  stories mainroad guestroom  \
# 0   13300000    7420           4          2        3      yes        no
# 1   12250000    8960           4          4        4      yes        no
# 2   12250000    8960           4          4        4      yes        no
# 3   12250000    9960           3          2        2      yes        no
# 4   12250000    9960           3          2        2      yes        no
# 5   12250000    8960           4          4        4      yes        no
# 6   12250000    8960           4          4        4      yes        no
# 7   12250000    9960           3          2        2      yes        no
# 8   12250000    9960           3          2        2      yes        no
# 9   12250000    8960           4          4        4      yes        no
# 10  12250000    8960           4          4        4      yes        no
# 11  12250000    9960           3          2        2      yes        no
# 12  12250000    9960           3          2        2      yes        no
# 13  12250000    8960           4          4        4      yes        no
# 14  12250000    8960           4          4        4      yes        no
# 15  12250000    9960           3          2        2      yes        no
# 16  12250000    9960           3          2        2      yes        no
# 17  12215000    7500           4          2        2      yes        no
# 18  11410000    7420           4          1        2      yes       yes
# 19  10850000    7500           3          3        1      yes        no
# 20  10150000    8580           4          3        4      yes        no
# 21  10150000    8580           4          3        4      yes        no
# 22  10150000   16200           5          3        2      yes        no
# 23  10150000   16200           5          3        2      yes        no
#
#    basement hotwaterheating airconditioning  parking prefarea  \
# 0        no              no             yes        2      yes
# 1        no              no             yes        3       no
# 2        no              no             yes        3       no
# 3       yes              no              no        2      yes
# 4       yes              no              no        2      yes
# 5        no              no             yes        3       no
# 6        no              no             yes        3       no
# 7       yes              no              no        2      yes
# 8       yes              no              no        2      yes
# 9        no              no             yes        3       no
# 10       no              no             yes        3       no
# 11      yes              no              no        2      yes
# 12      yes              no              no        2      yes
# 13       no              no             yes        3       no
# 14       no              no             yes        3       no
# 15      yes              no              no        2      yes
# 16      yes              no              no        2      yes
# 17      yes              no             yes        3      yes
# 18      yes              no             yes        2       no
# 19      yes              no             yes        2      yes
# 20       no              no             yes        2      yes
# 21       no              no             yes        2      yes
# 22       no              no              no        0       no
# 23       no              no              no        0       no
#
#    furnishingstatus  Unnamed: 13  offer  area_y  bedrooms_y
# 0         furnished          NaN      1     765           2
# 1         furnished          NaN      1     876           2
# 2         furnished          NaN      1     987           2
# 3    semi-furnished          NaN      1     876           2
# 4    semi-furnished          NaN      1     987           2
# 5         furnished          NaN      1     876           2
# 6         furnished          NaN      1     987           2
# 7    semi-furnished          NaN      1     876           2
# 8    semi-furnished          NaN      1     987           2
# 9         furnished          NaN      1     876           2
# 10        furnished          NaN      1     987           2
# 11   semi-furnished          NaN      1     876           2
# 12   semi-furnished          NaN      1     987           2
# 13        furnished          NaN      1     876           2
# 14        furnished          NaN      1     987           2
# 15   semi-furnished          NaN      1     876           2
# 16   semi-furnished          NaN      1     987           2
# 17        furnished          NaN      1    7654           2
# 18        furnished          NaN      1    9870           2
# 19   semi-furnished          NaN      1    6789           2
# 20   semi-furnished          NaN      1    5643           2
# 21   semi-furnished          NaN      1    5643           2
# 22      unfurnished          NaN      1    5643           2
# 23      unfurnished          NaN      1    5643           2

# %%
# Concatenate two datasets vertically
data_concatenated = pd.concat([data, data1], axis=0)
data_concatenated
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000  7420         4        2.0      3.0      yes        no       no
# 1   12250000  8960         4        4.0      4.0      yes        no       no
# 2   12250000  9960         3        2.0      2.0      yes        no      yes
# 3   12215000  7500         4        2.0      2.0      yes        no      yes
# 4   11410000  7420         4        1.0      2.0      yes       yes      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 3   12215000  7654         2        NaN      NaN      NaN       NaN      NaN
# 4   11410000  9870         2        NaN      NaN      NaN       NaN      NaN
# 5   10850000  6789         2        NaN      NaN      NaN       NaN      NaN
# 6   10150000  5643         2        NaN      NaN      NaN       NaN      NaN
# 7   10150000  5643         2        NaN      NaN      NaN       NaN      NaN
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0               no             yes      2.0      yes        furnished
# 1               no             yes      3.0       no        furnished
# 2               no              no      2.0      yes   semi-furnished
# 3               no             yes      3.0      yes        furnished
# 4               no             yes      2.0       no        furnished
# ..             ...             ...      ...      ...              ...
# 3              NaN             NaN      NaN      NaN              NaN
# 4              NaN             NaN      NaN      NaN              NaN
# 5              NaN             NaN      NaN      NaN              NaN
# 6              NaN             NaN      NaN      NaN              NaN
# 7              NaN             NaN      NaN      NaN              NaN
#
#     Unnamed: 13  offer
# 0           NaN    1.0
# 1           NaN    1.0
# 2           NaN    1.0
# 3           NaN    1.0
# 4           NaN    1.0
# ..          ...    ...
# 3           NaN    NaN
# 4           NaN    NaN
# 5           NaN    NaN
# 6           NaN    NaN
# 7           NaN    NaN
#
# [576 rows x 15 columns]

# %%
#Data transformation involves converting data into a suitable format or scale for analysis. Some common techniques include:
#Min-Max Scaling
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data['offer'] = scaler.fit_transform(data['offer'].values.reshape(-1, 1))

# %%
# Standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data['offer'] = scaler.fit_transform(data['offer'].values.reshape(-1, 1))
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 563   1750000  3620         2          1        1      yes        no       no
# 564   1750000  2910         3          1        1       no        no       no
# 565   1750000  3850         3          1        2      yes        no       no
# 566  12250000  8960         4          4        4      yes        no       no
# 567  12250000  9960         3          2        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 563              no              no        0       no      unfurnished
# 564              no              no        0       no        furnished
# 565              no              no        0       no      unfurnished
# 566              no             yes        3       no        furnished
# 567              no              no        2      yes   semi-furnished
#
#      Unnamed: 13  offer
# 0            NaN    0.0
# 1            NaN    0.0
# 2            NaN    0.0
# 3            NaN    0.0
# 4            NaN    0.0
# ..           ...    ...
# 563          NaN    0.0
# 564          NaN    0.0
# 565          NaN    0.0
# 566          NaN    0.0
# 567          NaN    0.0
#
# [568 rows x 15 columns]

# %%
#single column elimination
# Create DataFrame
df = pd.DataFrame(data)

# %%
# Print original dataset
print("Original dataset:")
print(df)
print()
# Out:
# Original dataset:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 563   1750000  3620         2          1        1      yes        no       no
# 564   1750000  2910         3          1        1       no        no       no
# 565   1750000  3850         3          1        2      yes        no       no
# 566  12250000  8960         4          4        4      yes        no       no
# 567  12250000  9960         3          2        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 563              no              no        0       no      unfurnished
# 564              no              no        0       no        furnished
# 565              no              no        0       no      unfurnished
# 566              no             yes        3       no        furnished
# 567              no              no        2      yes   semi-furnished
#
#      Unnamed: 13  offer
# 0            NaN    0.0
# 1            NaN    0.0
# 2            NaN    0.0
# 3            NaN    0.0
# 4            NaN    0.0
# ..           ...    ...
# 563          NaN    0.0
# 564          NaN    0.0
# 565          NaN    0.0
# 566          NaN    0.0
# 567          NaN    0.0
#
# [568 rows x 15 columns]

# %%
# Delete columns with a single value
df = df.loc[:, df.nunique() > 1]

# %%
# Print preprocessed dataset
print("Preprocessed dataset:")
print(df)
# Out:
# Preprocessed dataset:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 563   1750000  3620         2          1        1      yes        no       no
# 564   1750000  2910         3          1        1       no        no       no
# 565   1750000  3850         3          1        2      yes        no       no
# 566  12250000  8960         4          4        4      yes        no       no
# 567  12250000  9960         3          2        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 563              no              no        0       no      unfurnished
# 564              no              no        0       no        furnished
# 565              no              no        0       no      unfurnished
# 566              no             yes        3       no        furnished
# 567              no              no        2      yes   semi-furnished
#
# [568 rows x 13 columns]

# %%
#Eliminating duplicate rows in dataset
duplicate_rows = data[data.duplicated()]
duplicate_rows
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 545  12250000  8960         4          4        4      yes        no       no
# 546  12250000  9960         3          2        2      yes        no      yes
# 547   2100000  3360         2          1        1      yes        no       no
# 548   1960000  3420         5          1        2       no        no       no
# 549   1890000  1700         3          1        2      yes        no       no
# 550   1890000  3649         2          1        1      yes        no       no
# 551   1855000  2990         2          1        1       no        no       no
# 552   1820000  3000         2          1        1      yes        no      yes
# 553   1767150  2400         3          1        1       no        no       no
# 554   1750000  3620         2          1        1      yes        no       no
# 555   1750000  2910         3          1        1       no        no       no
# 556   1750000  3850         3          1        2      yes        no       no
# 557  12250000  8960         4          4        4      yes        no       no
# 558  12250000  9960         3          2        2      yes        no      yes
# 559   1890000  3649         2          1        1      yes        no       no
# 560   1855000  2990         2          1        1       no        no       no
# 561   1820000  3000         2          1        1      yes        no      yes
# 562   1767150  2400         3          1        1       no        no       no
# 563   1750000  3620         2          1        1      yes        no       no
# 564   1750000  2910         3          1        1       no        no       no
# 565   1750000  3850         3          1        2      yes        no       no
# 566  12250000  8960         4          4        4      yes        no       no
# 567  12250000  9960         3          2        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 545              no             yes        3       no        furnished
# 546              no              no        2      yes   semi-furnished
# 547              no              no        1       no      unfurnished
# 548              no              no        0       no      unfurnished
# 549              no              no        0       no      unfurnished
# 550              no              no        0       no      unfurnished
# 551              no              no        1       no      unfurnished
# 552              no              no        2       no      unfurnished
# 553              no              no        0       no   semi-furnished
# 554              no              no        0       no      unfurnished
# 555              no              no        0       no        furnished
# 556              no              no        0       no      unfurnished
# 557              no             yes        3       no        furnished
# 558              no              no        2      yes   semi-furnished
# 559              no              no        0       no      unfurnished
# 560              no              no        1       no      unfurnished
# 561              no              no        2       no      unfurnished
# 562              no              no        0       no   semi-furnished
# 563              no              no        0       no      unfurnished
# 564              no              no        0       no        furnished
# 565              no              no        0       no      unfurnished
# 566              no             yes        3       no        furnished
# 567              no              no        2      yes   semi-furnished
#
#      Unnamed: 13  offer
# 545          NaN    0.0
# 546          NaN    0.0
# 547          NaN    0.0
# 548          NaN    0.0
# 549          NaN    0.0
# 550          NaN    0.0
# 551          NaN    0.0
# 552          NaN    0.0
# 553          NaN    0.0
# 554          NaN    0.0
# 555          NaN    0.0
# 556          NaN    0.0
# 557          NaN    0.0
# 558          NaN    0.0
# 559          NaN    0.0
# 560          NaN    0.0
# 561          NaN    0.0
# 562          NaN    0.0
# 563          NaN    0.0
# 564          NaN    0.0
# 565          NaN    0.0
# 566          NaN    0.0
# 567          NaN    0.0

# %%
data.drop_duplicates(inplace=True)
data.reset_index(drop=True, inplace=True)
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
#      Unnamed: 13  offer
# 0            NaN    0.0
# 1            NaN    0.0
# 2            NaN    0.0
# 3            NaN    0.0
# 4            NaN    0.0
# ..           ...    ...
# 540          NaN    0.0
# 541          NaN    0.0
# 542          NaN    0.0
# 543          NaN    0.0
# 544          NaN    0.0
#
# [545 rows x 15 columns]
